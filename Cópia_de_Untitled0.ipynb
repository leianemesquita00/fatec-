# %% [markdown]
# <a href="https://colab.research.google.com/github/leianemesquita00/fatec-/blob/main/C%C3%B3pia_de_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {'coluna_1':[1.5,2.0,1.7,2.2,1.9],
        'coluna_2':[10.0,12.0,11.5,13.0,11.0],
        'coluna_3':[0,1,0,1,0],
        'coluna_4':[1,0,1,1,0],
        'coluna_5':[20.5,25.5,22.0,27.0,23.0]}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#    coluna_1  coluna_2  coluna_3  coluna_4  coluna_5
# 0       1.5      10.0         0         1      20.5
# 1       2.0      12.0         1         0      25.5
# 2       1.7      11.5         0         1      22.0
# 3       2.2      13.0         1         1      27.0
# 4       1.9      11.0         0         0      23.0

# %%
from google.colab import drive

# %%
drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
origem = '/content/drive/MyDrive/DATA/COMEXSTAT/'

# %%
drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
arquivo_1 = origem + 'EXP_2025.csv'
arquivo_2 = origem + 'EXP_2026.csv'
ncm = origem + 'NCM.csv'
pais = origem + 'PAIS.csv'
vias = origem + 'VIA.csv'
urf = origem + 'URF.csv'

# %%
exp25 = pd.read_csv(arquivo_1,low_memory=False,sep=";",encoding='UTF-8')
exp26 = pd.read_csv(arquivo_2,low_memory=False,sep=";",encoding='UTF-8')
expncm= pd.read_csv(ncm,low_memory=False,sep=";",encoding='latin-1')
exppais = pd.read_csv(pais,low_memory=False,sep=";",encoding='latin-1')
expvias = pd.read_csv(vias,low_memory=False,sep=";",encoding='UTF-8')
expurt= pd.read_csv(urf,low_memory=False,sep=";",encoding='latin-1')

# %%
exp25.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1709746 entries, 0 to 1709745
# Data columns (total 11 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   CO_ANO      int64
#  1   CO_MES      int64
#  2   CO_NCM      int64
#  3   CO_UNID     int64
#  4   CO_PAIS     int64
#  5   SG_UF_NCM   object
#  6   CO_VIA      int64
#  7   CO_URF      int64
#  8   QT_ESTAT    int64
#  9   KG_LIQUIDO  int64
#  10  VL_FOB      int64
# dtypes: int64(10), object(1)
# memory usage: 143.5+ MB

# %%
exp26.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982645 entries, 0 to 982644
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   CO_ANO      982645 non-null  int64
#  1   CO_MES      982645 non-null  int64
#  2   CO_NCM      982645 non-null  int64
#  3   CO_UNID     982645 non-null  int64
#  4   CO_PAIS     982645 non-null  int64
#  5   SG_UF_NCM   982645 non-null  object
#  6   CO_VIA      982645 non-null  int64
#  7   CO_URF      982645 non-null  int64
#  8   QT_ESTAT    982645 non-null  int64
#  9   KG_LIQUIDO  982645 non-null  int64
#  10  VL_FOB      982645 non-null  int64
# dtypes: int64(10), object(1)
# memory usage: 82.5+ MB

# %%
expncm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13746 entries, 0 to 13745
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CO_NCM          13746 non-null  int64
#  1   CO_UNID         13746 non-null  int64
#  2   CO_SH6          13746 non-null  int64
#  3   CO_PPE          13440 non-null  float64
#  4   CO_PPI          13440 non-null  float64
#  5   CO_FAT_AGREG    13724 non-null  float64
#  6   CO_CUCI_ITEM    13746 non-null  object
#  7   CO_CGCE_N3      13746 non-null  int64
#  8   CO_SIIT         13440 non-null  float64
#  9   CO_ISIC_CLASSE  13746 non-null  int64
#  10  CO_EXP_SUBSET   13438 non-null  float64
#  11  NO_NCM_POR      13746 non-null  object
#  12  NO_NCM_ESP      13746 non-null  object
#  13  NO_NCM_ING      13746 non-null  object
# dtypes: float64(5), int64(5), object(4)
# memory usage: 1.5+ MB

# %%
exp_final = pd.concat([exp25,exp26],ignore_index=True)

# %%
exp_final.head(5)
# Out:
#    CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA   CO_URF  \
# 0    2025       8  71039900       19      687        RS       4   817700
# 1    2025      12   2071412       10      741        SC       1   817800
# 2    2025      11  33059000       10      767        SP       4   817600
# 3    2025      11  56031330       10      845        SP       7  1017701
# 4    2025       6  21069090       10      365        SP       1   817800
#
#    QT_ESTAT  KG_LIQUIDO  VL_FOB
# 0     61690          13     203
# 1     83835       83835  111324
# 2       792         753   22012
# 3      2437        2437    8458
# 4      4800        4800   17304

# %%
exp_final.tail(5)
# Out:
#          CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  \
# 2692386    2026       4  25030090       10       63        SP       7
# 2692387    2026       3  90261011       11      249        SP       4
# 2692388    2026       2  72091600       10      493        SC       4
# 2692389    2026       3  97039000       11      521        SP       4
# 2692390    2026       1  85395100       11      149        SP       4
#
#           CO_URF  QT_ESTAT  KG_LIQUIDO  VL_FOB
# 2692386  1017500      5000        5000    4250
# 2692387   817600        78        4290   70067
# 2692388   817700         4           4      93
# 2692389   817600        19          25    2501
# 2692390   817700         7          17    7066

# %%
exp_final = exp_final.merge(exppais[['CO_PAIS','NO_PAIS']],on="CO_PAIS",how="left")
exp_final = exp_final.merge(expncm[['CO_NCM','NO_NCM_POR']],on='CO_NCM',how='left')

# %%
exp_final.head(10)
# Out:
#    CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA   CO_URF  \
# 0    2025       8  71039900       19      687        RS       4   817700
# 1    2025      12   2071412       10      741        SC       1   817800
# 2    2025      11  33059000       10      767        SP       4   817600
# 3    2025      11  56031330       10      845        SP       7  1017701
# 4    2025       6  21069090       10      365        SP       1   817800
# 5    2025       6  84099112       11      493        RS       1  1017700
# 6    2025       1  94051190       10      845        SC       7  1017701
# 7    2025       7  40139000       11      169        MG       4   817600
# 8    2025      11  84514021       11      586        SC       7   917500
# 9    2025       4  21069029       10      434        BA       1   517800
#
#    QT_ESTAT  KG_LIQUIDO  VL_FOB      NO_PAIS  \
# 0     61690          13     203  El Salvador
# 1     83835       83835  111324    Singapura
# 2       792         753   22012        Suíça
# 3      2437        2437    8458      Uruguai
# 4      4800        4800   17304    Indonésia
# 5        32          31    3089       México
# 6      2249        2249   14798      Uruguai
# 7       200         671   12680     Colômbia
# 8         1         130    9000     Paraguai
# 9         1           1       4      Libéria
#
#                                           NO_NCM_POR
# 0  Outras pedras preciosas (exceto diamantes) ou ...
# 1  Coxas com sobrecoxas não desossadas de galinha...
# 2                       Outras preparações capilares
# 3  Falsos tecidos de poliéster, de peso superior ...
# 4                    Outras preparações alimentícias
# 5  Blocos de cilindros, cabeçotes, etc, para moto...
# 6  Outros lustres e outras luminárias, elétricos,...
# 7                   Outras câmaras-de-ar de borracha
# 8  Máquinas para tingir tecidos em rolos, por pre...
# 9  Pós para preparações de cremes, sorvetes, flan...

# %%
coluna = 'NO_PAIS'
cp = exp_final[coluna].value_counts().sort_values(ascending=False)
print(f'total de operações{coluna}:')
print(cp)
# Out:
# total de operaçõesNO_PAIS:
# NO_PAIS
# Paraguai                     172240
# Argentina                    168833
# Estados Unidos               151029
# Uruguai                      114930
# Panamá                       113902
#                               ...
# Christmas (Navidad), Ilha         2
# Eritreia                          1
# Santa Helena                      1
# Coreia do Norte                   1
# Saara Ocidental                   1
# Name: count, Length: 247, dtype: int64

# %%
exp_final.to_csv(origem +'exp_final.csv',index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime

# Seu dataframe exp_final já está carregado

# Criar coluna de data a partir de CO_ANO e CO_MES
exp_final['DATA'] = pd.to_datetime(exp_final['CO_ANO'].astype(str) + '-' +
                                   exp_final['CO_MES'].astype(str) + '-01')

# Filtrar apenas o período desejado (janeiro 2025 a janeiro 2026)
data_inicio = '2025-01-01'
data_fim = '2026-01-31'
exp_filtrado = exp_final[(exp_final['DATA'] >= data_inicio) &
                         (exp_final['DATA'] <= data_fim)]

# Agrupar por mês e somar KG_LIQUIDO
importacoes_mensais = exp_filtrado.groupby('DATA')['KG_LIQUIDO'].sum().reset_index()
